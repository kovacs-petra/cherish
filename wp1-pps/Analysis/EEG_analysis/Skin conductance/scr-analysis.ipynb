# %%
import mne
import matplotlib.pyplot as plt
import numpy as np
import glob
import scipy

# %%
conditions = ['loom', 'rec', 'pps', 'eps']
data_dir = '//kfs/fileserver/Projektdaten/CherISH/data/wp-1/EEG/09_GSRfifData/approach1/'
data_files_loom = glob.glob(data_dir + '*loom-ave.fif')
data_files_rec  = glob.glob(data_dir + '*rec-ave.fif')
data_files_pps = glob.glob(data_dir + '*pps-ave.fif')
data_files_eps = glob.glob(data_dir + '*eps-ave.fif')

# %%
evokeds_loom = [
        mne.read_evokeds(l)[0]
        for l in data_files_loom
    ]

evokeds_rec = [
        mne.read_evokeds(r)[0]
        for r in data_files_rec
    ]

evokeds_pps = [
        mne.read_evokeds(p)[0]
        for p in data_files_pps
    ]

evokeds_eps = [
        mne.read_evokeds(e)[0]
        for e in data_files_eps
    ]
# Out:
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s03loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s04loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s05loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s06loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s07loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s08loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s09loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s10loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s11loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s12loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s13loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s14loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s15loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s16loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s17loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s18loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s19loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s20loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s21loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s22loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s23loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s24loom-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s03rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s04rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s05rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s06rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s07rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s08rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s09rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s10rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s11rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s12rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s13rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s14rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s15rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s16rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s17rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s18rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s19rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s20rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s21rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s22rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s23rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s24rec-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s03pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s04pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s05pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s06pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s07pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s08pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s09pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s10pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s11pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s12pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s13pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s14pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s15pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s16pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s17pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s18pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s19pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s20pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s21pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s22pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s23pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s24pps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s03eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s04eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s05eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s06eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s07eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s08eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s09eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s10eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s11eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s12eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s13eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s14eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s15eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s16eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s17eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s18eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s19eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s20eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s21eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s22eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s23eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied
# Reading \\kfs\fileserver\Projektdaten\CherISH\data\wp-1\EEG\09_GSRfifData\approach1\s24eps-ave.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =   -1000.00 ...    4800.00 ms (exported from FieldTrip: averaged data)
#         0 CTF compensation matrices available
#         nave = 2 - aspect type = 100
# No projector specified for this dataset. Please consider the method self.add_proj.
# No baseline correction applied

# %%
n_conditions = len(conditions)
n_observations = len(evokeds_loom) + len(evokeds_rec) + len(evokeds_pps) + len(evokeds_eps)

pval = 0.05  # arbitrary
dfn = n_conditions - 1  # degrees of freedom numerator
dfd = n_observations - n_conditions  # degrees of freedom denominator
thresh = scipy.stats.f.ppf(1 - pval, dfn=dfn, dfd=dfd)  # F distribution

# %%
## Cluster-based permutation test
l=np.stack([evo.get_data() for evo in evokeds_loom], axis =0)
l=np.transpose(l, (0,2,1))

r=np.stack([evo.get_data() for evo in evokeds_rec], axis =0)
r=np.transpose(r, (0,2,1))

p=np.stack([evo.get_data() for evo in evokeds_pps], axis =0)
p=np.transpose(p, (0,2,1))

e=np.stack([evo.get_data() for evo in evokeds_eps], axis =0)
e=np.transpose(e, (0,2,1))

X = [l,r,p,e]

# adj,_=mne.channels.find_ch_adjacency(diff_rec_loom[0].info, "eeg")

F_obs, clusters, cluster_pv, H0 = mne.stats.permutation_cluster_test(X,
                                                                threshold=None,
                                                                n_permutations=1000,
                                                                tail=0,
                                                                verbose=True)
# Out:
# Using a threshold of 2.713227
# stat_fun(H1): min=0.09846267449794323 max=0.8462822063663913
# Running initial clustering …
# Found 0 clusters
# C:\Users\pkovacs\AppData\Local\Temp\ipykernel_5340\3393470682.py:18: RuntimeWarning: Ignoring argument "tail", performing 1-tailed F-test
#   F_obs, clusters, cluster_pv, H0 = mne.stats.permutation_cluster_test(X,
# C:\Users\pkovacs\AppData\Local\Temp\ipykernel_5340\3393470682.py:18: RuntimeWarning: No clusters found, returning empty H0, clusters, and cluster_pv
#   F_obs, clusters, cluster_pv, H0 = mne.stats.permutation_cluster_test(X,

# %%
mne.viz.plot_compare_evokeds([evokeds_loom,evokeds_rec,evokeds_pps,evokeds_eps],
                            legend=True,
                             title='Loom (1), Rec (2), PPS (3), EPS (4)',
                            )
plt.show()
# Out:
# C:\Users\pkovacs\AppData\Local\Temp\ipykernel_1996\3007892683.py:1: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   mne.viz.plot_compare_evokeds([evokeds_loom,evokeds_rec,evokeds_pps,evokeds_eps],

# %%
mne.viz.plot_compare_evokeds([evokeds_loom,evokeds_rec],
                            legend=True,
                             title='Loom (1) and Rec (2)'
                            )
plt.show()
# Out:
# C:\Users\pkovacs\AppData\Local\Temp\ipykernel_1996\1183972708.py:1: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   mne.viz.plot_compare_evokeds([evokeds_loom,evokeds_rec],

# %%
mne.viz.plot_compare_evokeds([evokeds_pps,evokeds_eps],
                            legend=True,
                             title='PPS (1) and EPS (2)'
                            )
plt.show()
# Out:
# C:\Users\pkovacs\AppData\Local\Temp\ipykernel_1996\644170558.py:1: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   mne.viz.plot_compare_evokeds([evokeds_pps,evokeds_eps],

# %%
mne.viz.plot_compare_evokeds([evokeds_loom,evokeds_eps],
                            legend=True,
                             title='EPS onset: Loom (1) and EPS (2)'
                            )
plt.show()
# Out:
# C:\Users\pkovacs\AppData\Local\Temp\ipykernel_1996\3008895099.py:1: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   mne.viz.plot_compare_evokeds([evokeds_loom,evokeds_eps],

# %%
mne.viz.plot_compare_evokeds([evokeds_rec,evokeds_pps],
                            legend=True,
                             title='PPS onset: Rec (1) and PPS (2)'
                            )
plt.show()
# Out:
# C:\Users\pkovacs\AppData\Local\Temp\ipykernel_1996\3464036851.py:1: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   mne.viz.plot_compare_evokeds([evokeds_rec,evokeds_pps],

# %%
mne.viz.plot_compare_evokeds([evokeds_loom,evokeds_pps],
                            legend=True,
                             title='PPS offset: Loom (1) and PPS (2)'
                            )
plt.show()
# Out:
# C:\Users\pkovacs\AppData\Local\Temp\ipykernel_1996\353728929.py:1: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   mne.viz.plot_compare_evokeds([evokeds_loom,evokeds_pps],

# %%
mne.viz.plot_compare_evokeds([evokeds_rec,evokeds_eps],
                            legend=True,
                             title='EPS offset: Rec (1) and EPS (2)'
                            )
plt.show()
# Out:
# C:\Users\pkovacs\AppData\Local\Temp\ipykernel_1996\3839262068.py:1: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   mne.viz.plot_compare_evokeds([evokeds_rec,evokeds_eps],

# %%
evokeds_loom.nave
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 evokeds_loom.nave
#
# AttributeError: 'list' object has no attribute 'nave'
